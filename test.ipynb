# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_distances, euclidean_distances
from pylab import rcParams
from pydtw.dtw import *

# %%
rcParams['figure.figsize'] = 15, 6

# %%
n = 200
m = 10
x = np.sin(np.linspace(0,2*np.pi,n+m))*3 + np.random.rand(n+m)*0.5 + np.cos(np.linspace(0,5*np.pi,n+m))*2
y = np.sin(np.linspace(0,2*np.pi,n))*3 + np.random.rand(n)*0.5 + np.cos(np.linspace(0,5*np.pi,n))*1.5

# %%
print(x.shape)
print(y.shape)
# Out:
# (210,)
# (200,)

# %%
warp = dtw(x,y,metric=l1_norm)

# %%
warp
# Out:
# Path : [[0 0]
#  [0 1]
#  [0 2]]...
# Distances : [0.4858 0.4069 0.4664]...
# Total :110.3208

# %%
warp.plot()

# %%
% timeit dtw(x,y)
# Out:
# 2.56 ms ± 243 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
warp = dtw(x,y,metric=l2_norm)

# %%
warp
# Out:
# Path : [[0 0]
#  [0 1]
#  [0 2]]...
# Distances : [0.236  0.1656 0.2176]...
# Total :80.5758

# %%
warp.plot()

# %%
% timeit dtw(x,y)
# Out:
# 2.61 ms ± 144 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
warp = ddtw(x,y)

# %%
warp
# Out:
# Path : [[0 0]
#  [0 0]
#  [0 1]]...
# Distances : [0.     0.0677 0.0194]...
# Total :9.0263

# %%
warp.plot()

# %%
% timeit ddtw(x,y)
# Out:
# 2.37 ms ± 204 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
